# %% [markdown]
# # spread polynomial study
#
# thanks to Federico Rocca for sharing this:
# - https://www.dropbox.com/s/g2bdsg397us3m41/Spreads%20-%20Jupyter%20Notebook.pdf?dl=0
#
# and to Dr. Wildberger.
#
# Here are some of the changes and additions from Federico's:
#
# - Set `Spread` function to ensure we get a Sympy polynomial, which allows for easy extraction of the coefficients.
# - cast the ints as sympy Integers. This removes the floating point values from the expressions
# - created a list of coefficients in `results`. Reversed each set so they are ordered low to high (allows for easy stacking)

# %%
from sympy import symbols, Function, Indexed, Rational, Expr, Poly, Integer
from sympy import Sum, factorial, binomial, oo, IndexedBase
# import sympy.functions as sym
from sympy import init_printing
init_printing(use_latex=True)
from sympy import pprint
from sympy import Symbol
from IPython.display import display
import math

def Spread(n):
    s = Symbol('s')
    n = Integer(n)
    p = Integer(0)
    for k in range(1, n+1):
        k = Integer(k)
        p += Poly(((-4)**(k-1))/(n+k) * binomial(n+k,2*k) * s**k)
    return 2*n*p

results = []

count = 10

for n in range(count):
    spr = Spread(n)
    display((Indexed('S',n), spr))
    if hasattr(spr, 'expr'):
        display(spr.expr )
    if hasattr(spr, 'coeffs'):
        cfs = spr.all_coeffs()
        cfs.reverse()
        print(cfs)
        results.append(cfs)
        print('-----------------------')
# Out:
# (S[0], 0)
# (S[1], Poly(s, s, domain='QQ'))
# s
# [0, 1]
# -----------------------
# (S[2], Poly(-4*s**2 + 4*s, s, domain='ZZ'))
#      2
# - 4⋅s  + 4⋅s
# [0, 4, -4]
# -----------------------
# (S[3], Poly(16*s**3 - 24*s**2 + 9*s, s, domain='QQ'))
#     3       2
# 16⋅s  - 24⋅s  + 9⋅s
# [0, 9, -24, 16]
# -----------------------
# (S[4], Poly(-64*s**4 + 128*s**3 - 80*s**2 + 16*s, s, domain='ZZ'))
#       4        3       2
# - 64⋅s  + 128⋅s  - 80⋅s  + 16⋅s
# [0, 16, -80, 128, -64]
# -----------------------
# (S[5], Poly(256*s**5 - 640*s**4 + 560*s**3 - 200*s**2 + 25*s, s, domain='QQ'))
#      5        4        3        2
# 256⋅s  - 640⋅s  + 560⋅s  - 200⋅s  + 25⋅s
# [0, 25, -200, 560, -640, 256]
# -----------------------
# (S[6], Poly(-1024*s**6 + 3072*s**5 - 3456*s**4 + 1792*s**3 - 420*s**2 + 36*s, s, domain='QQ'))
#         6         5         4         3        2
# - 1024⋅s  + 3072⋅s  - 3456⋅s  + 1792⋅s  - 420⋅s  + 36⋅s
# [0, 36, -420, 1792, -3456, 3072, -1024]
# -----------------------
# (S[7], Poly(4096*s**7 - 14336*s**6 + 19712*s**5 - 13440*s**4 + 4704*s**3 - 784*s**2 + 49*s, s, domain='QQ'))
#       7          6          5          4         3        2
# 4096⋅s  - 14336⋅s  + 19712⋅s  - 13440⋅s  + 4704⋅s  - 784⋅s  + 49⋅s
# [0, 49, -784, 4704, -13440, 19712, -14336, 4096]
# -----------------------
# (S[8], Poly(-16384*s**8 + 65536*s**7 - 106496*s**6 + 90112*s**5 - 42240*s**4 + 10752*s**3 - 1344*s**2 + 64*s, s, domain='ZZ'))
#          8          7           6          5          4          3         2
# - 16384⋅s  + 65536⋅s  - 106496⋅s  + 90112⋅s  - 42240⋅s  + 10752⋅s  - 1344⋅s  + 64⋅s
# [0, 64, -1344, 10752, -42240, 90112, -106496, 65536, -16384]
# -----------------------
# (S[9], Poly(65536*s**9 - 294912*s**8 + 552960*s**7 - 559104*s**6 + 329472*s**5 - 114048*s**4 + 22176*s**3 - 2160*s**2 + 81*s, s, domain='QQ'))
#        9           8           7           6           5           4          3         2
# 65536⋅s  - 294912⋅s  + 552960⋅s  - 559104⋅s  + 329472⋅s  - 114048⋅s  + 22176⋅s  - 2160⋅s  + 81⋅s
# [0, 81, -2160, 22176, -114048, 329472, -559104, 552960, -294912, 65536]
# -----------------------

# %% [markdown]
# The alternating domains on the Poly's are an iteresting result

# %%
for cfs in results:
    print(cfs)
# Out:
# [0, 1]
# [0, 4, -4]
# [0, 9, -24, 16]
# [0, 16, -80, 128, -64]
# [0, 25, -200, 560, -640, 256]
# [0, 36, -420, 1792, -3456, 3072, -1024]
# [0, 49, -784, 4704, -13440, 19712, -14336, 4096]
# [0, 64, -1344, 10752, -42240, 90112, -106496, 65536, -16384]
# [0, 81, -2160, 22176, -114048, 329472, -559104, 552960, -294912, 65536]
